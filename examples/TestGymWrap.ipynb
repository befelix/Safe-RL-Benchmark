# %%
import sys, os

sys.path.append(os.path.abspath('..'))

from SafeRLBench import config
from SafeRLBench.algo import PolicyGradient
from SafeRLBench.envs import GymWrap
from SafeRLBench.policy import DiscreteLinearPolicy
from SafeRLBench.spaces import BoundedSpace

import gym

import logging

# %%
config.logger_set_level(logging.DEBUG)
config.logger_add_stream_handler()

# %%
env = gym.make('MountainCar-v0')
wrap = GymWrap(env, 200, render=True)
# Out:
# [2017-02-08 14:42:57,541] Making new env: MountainCar-v0

# %%
policy = DiscreteLinearPolicy(2, 1)
policy.parameter_space = BoundedSpace(-2, 2, (2,))
opt = PolicyGradient(wrap, policy, estimator='central_fd', eps=0.0000000001, var=5)

# %%
opt.optimize()

# %%
for i in range(100):
    wrap.environment.render()
    print(wrap.update(1))
# Out:
# [2017-02-01 11:52:12,245] You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
# (1, array([ 0.03971692,  0.18127836,  0.01767499, -0.33329185]), 1.0)
# (1, array([ 0.04334249,  0.37614434,  0.01100916, -0.62034899]), 1.0)
# (1, array([ 0.05086538,  0.57111082, -0.00139782, -0.90954436]), 1.0)
# (1, array([ 0.06228759,  0.76625166, -0.01958871, -1.20266629]), 1.0)
# (1, array([ 0.07761263,  0.96162135, -0.04364204, -1.50142331]), 1.0)
# (1, array([ 0.09684505,  1.1572452 , -0.0736705 , -1.80740638]), 1.0)
# (1, array([ 0.11998996,  1.35310766, -0.10981863, -2.1220427 ]), 1.0)
# (1, array([ 0.14705211,  1.54913815, -0.15225948, -2.44653893]), 1.0)
# (1, array([ 0.17803487,  1.74519443, -0.20119026, -2.78181258]), 1.0)
# (1, array([ 0.21293876,  1.94104352, -0.25682651, -3.12841234]), 1.0)
# (1, array([ 0.25175963,  2.1363415 , -0.31939476, -3.48643057]), 0.0)
# (1, array([ 0.29448646,  2.33061379, -0.38912337, -3.85541486]), 0.0)
# (1, array([ 0.34109874,  2.52323962, -0.46623167, -4.23429009]), 0.0)
# (1, array([ 0.39156353,  2.71344497, -0.55091747, -4.62130666]), 0.0)
# (1, array([ 0.44583243,  2.90031001, -0.6433436 , -5.01403262]), 0.0)
# (1, array([ 0.50383863,  3.08279696, -0.74362426, -5.40940578]), 0.0)
# (1, array([ 0.56549457,  3.25980337, -0.85181237, -5.80385235]), 0.0)
# (1, array([ 0.63069064,  3.43024278, -0.96788942, -6.19346242]), 0.0)
# (1, array([ 0.69929549,  3.59315046, -1.09175867, -6.57419007]), 0.0)
# (1, array([ 0.7711585 ,  3.74780694, -1.22324247, -6.94202475]), 0.0)
# (1, array([ 0.84611464,  3.89386876, -1.36208296, -7.29306886]), 0.0)
# (1, array([ 0.92399202,  4.03149452, -1.50794434, -7.62346293]), 0.0)
# (1, array([ 1.00462191,  4.1614559 , -1.6604136 , -7.92912685]), 0.0)
# (1, array([ 1.08785102,  4.28522432, -1.81899614, -8.20533162]), 0.0)
# (1, array([ 1.17355551,  4.40502195, -1.98310277, -8.44617824]), 0.0)
# (1, array([ 1.26165595,  4.52381646, -2.15202633, -8.64413511]), 0.0)
# (1, array([ 1.35213228,  4.64522398, -2.32490904, -8.78986814]), 0.0)
# (1, array([ 1.44503676,  4.77327068, -2.5007064 , -8.87265939]), 0.0)
# (1, array([ 1.54050217,  4.91196968, -2.67815959, -8.88167914]), 0.0)
# (1, array([ 1.63874157,  5.06472054, -2.85579317, -8.80814475]), 0.0)
# (1, array([ 1.74003598,  5.2336417 , -3.03195607, -8.64792688]), 0.0)
# (1, array([ 1.84470881,  5.41905809, -3.2049146 , -8.40364079]), 0.0)
# (1, array([ 1.95308997,  5.61938693, -3.37298742, -8.08514554]), 0.0)
# (1, array([ 2.06547771,  5.83151977, -3.53469033, -7.70800252]), 0.0)
# (1, array([ 2.18210811,  6.05155714, -3.68885038, -7.29050367]), 0.0)
# (1, array([ 2.30313925,  6.2755958 , -3.83466045, -6.85054324]), 0.0)
# (1, array([ 2.42865117,  6.50030718, -3.97167132, -6.40340438]), 0.0)
# (1, array([ 2.55865731,  6.72321045, -4.09973941, -5.96080834]), 0.0)
# (1, array([ 2.69312152,  6.94269032, -4.21895557, -5.53096529]), 0.0)
# (1, array([ 2.83197532,  7.15786765, -4.32957488, -5.11915709]), 0.0)
# (1, array([ 2.97513268,  7.36841829, -4.43195802, -4.72846644]), 0.0)
# (1, array([ 3.12250104,  7.57439824, -4.52652735, -4.36043763]), 0.0)
# (1, array([ 3.27398901,  7.77610026, -4.6137361 , -4.01559128]), 0.0)
# (1, array([ 3.42951101,  7.97394692, -4.69404793, -3.69379103]), 0.0)
# (1, array([ 3.58898995,  8.16841625, -4.76792375, -3.39449062]), 0.0)
# (1, array([ 3.75235828,  8.35999296, -4.83581356, -3.11689442]), 0.0)
# (1, array([ 3.91955814,  8.54913856, -4.89815145, -2.86005991]), 0.0)
# (1, array([ 4.09054091,  8.73627463, -4.95535265, -2.62296287]), 0.0)
# (1, array([ 4.2652664 ,  8.92177503, -5.0078119 , -2.40453949]), 0.0)
# (1, array([ 4.4437019 ,  9.10596401, -5.05590269, -2.20371425]), 0.0)
# (1, array([ 4.62582118,  9.28911777, -5.09997698, -2.0194192 ]), 0.0)
# (1, array([ 4.81160354,  9.47146812, -5.14036536, -1.85060786]), 0.0)
# (1, array([ 5.0010329 ,  9.65320723, -5.17737752, -1.69626539]), 0.0)
# (1, array([ 5.19409704,  9.83449259, -5.21130283, -1.55541629]), 0.0)
# (1, array([  5.39078689,  10.015452  ,  -5.24241115,  -1.4271301 ]), 0.0)
# (1, array([  5.59109593,  10.19618815,  -5.27095376,  -1.31052553]), 0.0)
# (1, array([  5.7950197 ,  10.37678285,  -5.29716427,  -1.20477322]), 0.0)
# (1, array([  6.00255535,  10.55730066,  -5.32125973,  -1.10909739]), 0.0)
# (1, array([  6.21370137,  10.73779204,  -5.34344168,  -1.0227766 ]), 0.0)
# (1, array([  6.42845721,  10.91829609,  -5.36389721,  -0.94514372]), 0.0)
# (1, array([  6.64682313,  11.09884278,  -5.38280009,  -0.87558529]), 0.0)
# (1, array([  6.86879999,  11.27945484,  -5.40031179,  -0.81354042]), 0.0)
# (1, array([  7.09438908,  11.46014935,  -5.4165826 ,  -0.75849942]), 0.0)
# (1, array([  7.32359207,  11.64093895,  -5.43175259,  -0.71000213]), 0.0)
# (1, array([  7.55641085,  11.82183299,  -5.44595263,  -0.66763619]), 0.0)
# (1, array([  7.79284751,  12.0028383 ,  -5.45930535,  -0.63103526]), 0.0)
# (1, array([  8.03290427,  12.18395992,  -5.47192606,  -0.59987721]), 0.0)
# (1, array([  8.27658347,  12.36520171,  -5.4839236 ,  -0.57388248]), 0.0)
# (1, array([  8.52388751,  12.54656676,  -5.49540125,  -0.55281246]), 0.0)
# (1, array([  8.77481884,  12.72805778,  -5.5064575 ,  -0.53646813]), 0.0)
# (1, array([  9.02938   ,  12.90967749,  -5.51718686,  -0.52468876]), 0.0)
# (1, array([  9.28757355,  13.09142879,  -5.52768064,  -0.5173509 ]), 0.0)
# (1, array([  9.54940212,  13.27331509,  -5.53802766,  -0.51436755]), 0.0)
# (1, array([  9.81486843,  13.45534047,  -5.54831501,  -0.51568756]), 0.0)
# (1, array([ 10.08397523,  13.63750986,  -5.55862876,  -0.52129527]), 0.0)
# (1, array([ 10.35672543,  13.81982926,  -5.56905467,  -0.5312104 ]), 0.0)
# (1, array([ 10.63312202,  14.00230587,  -5.57967887,  -0.54548817]), 0.0)
# (1, array([ 10.91316813,  14.18494833,  -5.59058864,  -0.5642197 ]), 0.0)
# (1, array([ 11.1968671 ,  14.36776683,  -5.60187303,  -0.5875327 ]), 0.0)
# (1, array([ 11.48422244,  14.55077335,  -5.61362369,  -0.61559233]), 0.0)
# (1, array([ 11.7752379 ,  14.73398184,  -5.62593553,  -0.64860247]), 0.0)
# (1, array([ 12.06991754,  14.91740848,  -5.63890758,  -0.6868071 ]), 0.0)
# (1, array([ 12.36826571,  15.10107184,  -5.65264372,  -0.73049208]), 0.0)
# (1, array([ 12.67028715,  15.28499319,  -5.66725356,  -0.7799871 ]), 0.0)
# (1, array([ 12.97598701,  15.46919674,  -5.68285331,  -0.83566785]), 0.0)
# (1, array([ 13.28537095,  15.65370988,  -5.69956666,  -0.89795841]), 0.0)
# (1, array([ 13.59844514,  15.83856344,  -5.71752583,  -0.9673338 ]), 0.0)
# (1, array([ 13.91521641,  16.02379195,  -5.73687251,  -1.0443225 ]), 0.0)
# (1, array([ 14.23569225,  16.20943375,  -5.75775896,  -1.129509  ]), 0.0)
# (1, array([ 14.55988093,  16.39553111,  -5.78034914,  -1.223536  ]), 0.0)
# (1, array([ 14.88779155,  16.58213016,  -5.80481986,  -1.32710624]), 0.0)
# (1, array([ 15.21943415,  16.76928057,  -5.83136198,  -1.44098334]), 0.0)
# (1, array([ 15.55481976,  16.95703491,  -5.86018165,  -1.5659915 ]), 0.0)
# (1, array([ 15.89396046,  17.14544756,  -5.89150148,  -1.70301309]), 0.0)
# (1, array([ 16.23686941,  17.33457283,  -5.92556174,  -1.85298352]), 0.0)
# (1, array([ 16.58356087,  17.52446225,  -5.96262141,  -2.01688212]), 0.0)
# (1, array([ 16.93405011,  17.71516046,  -6.00295905,  -2.19571767]), 0.0)
# (1, array([ 17.28835332,  17.90669951,  -6.04687341,  -2.39050667]), 0.0)
# (1, array([ 17.64648731,  18.09909081,  -6.09468354,  -2.60224235]), 0.0)
# (1, array([ 18.00846913,  18.29231448,  -6.14672839,  -2.83185184]), 0.0)
